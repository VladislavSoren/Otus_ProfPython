# %% [markdown]
# Open Data Science
#
# Задание: проанализировать отĸрытый массив данных на свой выбор. Датасеты
# исĸать, например, тут: https://toolbox.google.com/datasetsearch,
# http://data.gov.ru/opendata, https://github.com/caesar0301/awesome-public-datasets,
# https://www.forbes.com/sites/bernardmarr/2016/02/12/big-data-35-brilliant-and-free-data-sources-for-2016/#4cc5e370b54d
# Цель задания: на праĸтиĸе познаĸомиться с pandas, попробовать поработать с
# "реальными" данными и потренироваться в представлении результатов своих
# исследований.
# Критерии успеха: задание опционально, ĸритерием успеха является
# проанализированный (с использованием jypiter notebook, pandas и т.п.) ĸаĸим угодно образом массив данных, заинтересовавший студента. Далее успешность
# определяется review.

# %% [markdown]
# Для анализа взята мировая статистика по рождаемости.
# Источник: https://www.kaggle.com/datasets/saadaziz1985/population-collapse/?select=country_groups_all.csv
#
# Файлы из источника находятся в рамках папки data.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
sns.set_theme(rc={'figure.figsize':(11.7,8.27)})

data_birth = pd.read_csv('./data/total_birth_rate.csv', encoding='utf-8')

# %%
population = {'Year': [], 'rus_birth_rate': [], 'Year1': [], 'usa_birth_rate': []}
for x in data_birth.loc[data_pop.query('economy == "RUS"').index[0]][1:].items():
    population['Year'].append(x[0][-2:])
    population['rus_birth_rate'].append(x[1])
    
for x in data_birth.loc[data_pop.query('economy == "USA"').index[0]][1:].items():
    population['Year1'].append(x[0][-2:])
    population['usa_birth_rate'].append(x[1])

sns.lineplot(data=population);

# %% [markdown]
# По графикам видно, что рождаемость в Америке почти всегда неуклонно падала, в России же до 15 года наблюдался рост, затем началось резкое падение, по тендеции опережающем американскую.

# %%
data_death = pd.read_csv('./data/total_death_rate.csv', encoding='utf-8')

# %%
population = {'Year': [], 'rus_death_rate': [], 'Year1': [], 'usa_death_rate': []}
for x in data_death.loc[data_pop.query('economy == "RUS"').index[0]][1:].items():
    population['Year'].append(x[0][-2:])
    population['rus_death_rate'].append(x[1])
    
for x in data_death.loc[data_pop.query('economy == "USA"').index[0]][1:].items():
    population['Year1'].append(x[0][-2:])
    population['usa_death_rate'].append(x[1])

sns.lineplot(data=population);

# %% [markdown]
# Очевидно, что смертность в России всегда выше чем в штатах, но она неуклонно уменьшалась до 19 года, но после настал резкий её рост. В штатах же она была стабильно, но так же после 19 года заметен её рост.

# %%
population = {'Year': [], 'rus_birth_rate': [], 'Year1': [], 'rus_death_rate': []}
for x in data_birth.loc[data_pop.query('economy == "RUS"').index[0]][1:].items():
    population['Year'].append(x[0][-2:])
    population['rus_birth_rate'].append(x[1])
    
for x in data_death.loc[data_pop.query('economy == "RUS"').index[0]][1:].items():
    population['Year1'].append(x[0][-2:])
    population['rus_death_rate'].append(x[1])

sns.lineplot(data=population);

# %% [markdown]
# Графики уже были объеснены выше, но здесь в сравнении отлично видна разница между рождаемость и смертность в различные годы.

# %%
data = pd.read_csv('./data/all_indicators.csv', encoding='utf-8')

# %%
data.head()
# Out:
#   economy  Pop-YR2002  Pop-YR2021      Pop%  Life-YR2002  Life-YR2021  \
# 0     ABW       91781      106537  0.160774    73.726000    74.626000
# 1     AFE   422741118   702977106  0.662902    52.540794    62.454590
# 2     AFG    21000256    40099462  0.909475    56.454000    61.982000
# 3     AFW   284952322   478185907  0.678126    50.927848    56.988657
# 4     AGO    17516139    34503774  0.969828    47.386000    61.643000
#
#       Life%  Fer-YR2002  Fer-YR2021      Fer%  ...  Death-YR2021    Death%  \
# 0  0.012207    1.763000    1.180000 -0.330686  ...     11.235000  0.750000
# 1  0.188688    5.430475    4.354709 -0.198098  ...      8.036899 -0.396157
# 2  0.097920    7.339000    4.643000 -0.367353  ...      7.344000 -0.348936
# 3  0.119008    5.967267    4.978662 -0.165671  ...     10.678952 -0.288397
# 4  0.300869    6.567000    5.304000 -0.192325  ...      8.009000 -0.536382
#
#    Birth-YR2002  Birth-YR2021    Birth%  Med_Age-YR2002  Med_Age-YR2021  \
# ...

# %%
data.tail()
# Out:
#     economy  Pop-YR2002  Pop-YR2021      Pop%  Life-YR2002  Life-YR2021  \
# 261     XKX     1702310     1786038  0.049185       74.676       76.806
# 262     YEM    19660653    32981641  0.677546       63.906       63.753
# 263     ZAF    47661514    59392255  0.246126       55.666       62.341
# 264     ZMB    10508294    19473125  0.853120       46.979       61.223
# 265     ZWE    11984644    15993524  0.334501       44.565       59.253
#
#         Life%  Fer-YR2002  Fer-YR2021      Fer%  ...  Death-YR2021    Death%  \
# 261  0.028523       2.533       1.522 -0.399131  ...         7.220  0.439968
# 262 -0.002394       5.937       3.795 -0.360788  ...         6.845 -0.049702
# 263  0.119912       2.324       2.374  0.021515  ...        11.432 -0.029871
# 264  0.303199       5.792       4.308 -0.256215  ...         6.973 -0.544010
# 265  0.329586       3.887       3.491 -0.101878  ...         9.057 -0.465758
#
# ...

# %% [markdown]
# Покажем размер таблицы

# %%
data.shape
# Out:
# (266, 21)

# %%
Получим 15 государств с минимальным числом населения по состоянию на 2002 год.

# %%
sns.histplot(data=data.sort_values(by='Pop-YR2002')[:10:], x='economy', y='Pop-YR2002', hue='economy')
# Out:
# <Axes: xlabel='economy', ylabel='Pop-YR2002'>

# %% [markdown]
# Получим 10 государств и регионов с максимальным населением по состоянию на 2002 год (выгрузка идет с 14 строки, т.к. выше идут показатели общемировые по и разным регионам в сумме).

# %%
sns.histplot(data.sort_values(by='Pop-YR2002', ascending=False)[14:25:], x='economy', y='Pop-YR2002', hue='economy')
# Out:
# <Axes: xlabel='economy', ylabel='Pop-YR2002'>

# %% [markdown]
# Сравним это с минимальным населением по состоянию на 2021 год.

# %%
sns.histplot(data=data.sort_values(by='Pop-YR2002')[:10:], x='economy', y='Pop-YR2021', hue='economy')
# Out:
# <Axes: xlabel='economy', ylabel='Pop-YR2021'>

# %% [markdown]
# И с максимальной численностью населения в странах и регионах по состоянию на 2021 год.

# %%
sns.histplot(data.sort_values(by='Pop-YR2002', ascending=False)[14:25:], x='economy', y='Pop-YR2021', hue='economy')
# Out:
# <Axes: xlabel='economy', ylabel='Pop-YR2021'>

# %% [markdown]
# Отследим динамику изменения численности населения в России с 2000 по 2021 год.

# %%
data_pop = pd.read_csv('./data/total_population.csv', encoding='utf-8')
rus_population = {'Year': [], 'Population': []}
for x in data_pop.loc[data_pop.query('economy == "RUS"').index[0]][1:].items():
    rus_population['Year'].append(x[0][-2:])
    rus_population['Population'].append(x[1])
sns.lineplot(data=rus_population, x='Year', y='Population')
# Out:
# <Axes: xlabel='Year', ylabel='Population'>

# %% [markdown]
# Сравним изменение численности населения с Китаем (выборка с 2000 по 2021 год).

# %%
chn_population = {'Year': [], 'Population': []}
for x in data_pop.loc[data_pop.query('economy == "CHN"').index[0]][1:].items():
    chn_population['Year'].append(x[0][-2:])
    chn_population['Population'].append(x[1])
sns.lineplot(data=chn_population, x='Year', y='Population')
# Out:
# <Axes: xlabel='Year', ylabel='Population'>
